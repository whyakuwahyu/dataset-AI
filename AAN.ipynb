# %% [markdown]
# <a href="https://colab.research.google.com/github/whyakuwahyu/dataset-AI/blob/main/AAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile

local_zip = '/tmp/nangka_and_sirih_filtered.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
base_dir = '/tmp/nangka_and_sirih_filtered'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_nangka_dir = os.path.join(train_dir, 'nangka')
train_sirih_dir = os.path.join(train_dir, 'sirih')

validation_nangka_dir = os.path.join(validation_dir, 'nangka')
validation_sirih_dir = os.path.join(validation_dir, 'sirih')

# %%
# Cek penamaan image yang ada di folder train_nangka_dir dan train_sirih_dir
print(os.listdir(train_nangka_dir)[:10])
print(os.listdir(train_sirih_dir)[:10])
# Out:
# ['025.jpg', '002.jpg', '027.jpg', '015.jpg', '019.jpg', '035.jpg', '009.jpg', '036.jpg', '046.jpg', '011.jpg']
# ['025.jpg', '002.jpg', '027.jpg', '015.jpg', '019.jpg', '035.jpg', '009.jpg', '036.jpg', '046.jpg', '011.jpg']

# %%
# Cek jumlah data train dan data validation
print('total training Nangka images:', len(os.listdir(train_nangka_dir)))
print('total training Sirih images:', len(os.listdir(train_sirih_dir)))
print('total validation Nangka images:', len(os.listdir(validation_nangka_dir)))
print('total validation Sirih images:', len(os.listdir(validation_sirih_dir)))
# Out:
# total training Nangka images: 50
# total training Sirih images: 50
# total validation Nangka images: 50
# total validation Sirih images: 50

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows = 4
ncols = 4

pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_Nangka_pix = [os.path.join(train_nangka_dir, fname) 
                for fname in os.listdir(train_nangka_dir)[pic_index-8:pic_index]]
next_Sirih_pix = [os.path.join(train_sirih_dir, fname) 
                for fname in os.listdir(train_sirih_dir)[pic_index-8:pic_index]]

for i, img_path in enumerate(next_Nangka_pix+next_Sirih_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import cv2
import numpy as np

# Gather data train
train_data = []
train_label = []
for r, d, f in os.walk(train_dir):
    for file in f:
        if ".jpg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (150,150))
            train_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            train_label.append(label)

train_data = np.array(train_data)
train_label = np.array(train_label)

# %%
# Gather data validation
val_data = []
val_label = []
for r, d, f in os.walk(validation_dir):
    for file in f:
        if ".jpg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (150,150))
            val_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            val_label.append(label)

val_data = np.array(val_data)
val_label = np.array(val_label)

# %%
# Tampilkan shape dari data train dan data validation
print("Train Data = ", train_data.shape)
print("Train Label = ", train_label.shape)
print("Validation Data = ", val_data.shape)
print("Validation Label = ", val_label.shape)
# Out:
# Train Data =  (100, 150, 150, 3)
# Train Label =  (100,)
# Validation Data =  (100, 150, 150, 3)
# Validation Label =  (100,)

# %%
# Normalisasi dataset
print("Data sebelum di-normalisasi ", train_data[0][0][0])

x_train = train_data.astype('float32') / 255.0
x_val = val_data.astype('float32') / 255.0
print("Data setelah di-normalisasi ", x_train[0][0][0])
# Out:
# Data sebelum di-normalisasi  [189 185 184]
# Data setelah di-normalisasi  [0.7411765  0.7254902  0.72156864]

# %%
# Transformasi label encoder
from sklearn.preprocessing import LabelEncoder

print("Label sebelum di-encoder ", train_label[995:1005])

lb = LabelEncoder()
y_train = lb.fit_transform(train_label)
y_val = lb.fit_transform(val_label)

print("Label setelah di-encoder ", y_train[995:1005])
# Out:
# Label sebelum di-encoder  []
# Label setelah di-encoder  []

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model

# %%
# Buat model dengan 1 input layer, 1 hidden layer, dan 1 output layer
img_input = layers.Input(shape=(150, 150, 3)) # layer input
x = layers.Flatten()(img_input) # ubah dari matriks 150x150x3 menjadi vektor
x = layers.Dense(128, activation='relu')(x) # hidden layer 1 dengan 128 neuron
output = layers.Dense(1, activation='sigmoid')(x) # output layer dengan 1 neuron (binary)

# Definisikan modelnya
model = Model(img_input, output)

# %%
# Tampilkan model summary
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  flatten (Flatten)           (None, 67500)             0
#
#  dense (Dense)               (None, 128)               8640128
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 8,640,257
# Trainable params: 8,640,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(loss='binary_crossentropy',
              optimizer=Adam(lr=0.001),
              metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
H = model.fit(x_train, y_train, batch_size=20, epochs=50, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 1s 111ms/step - loss: 20.0074 - acc: 0.5500 - val_loss: 13.9141 - val_acc: 0.5000
# Epoch 2/50
# 5/5 [==============================] - 0s 69ms/step - loss: 6.2769 - acc: 0.5800 - val_loss: 1.4942 - val_acc: 0.5000
# Epoch 3/50
# 5/5 [==============================] - 0s 80ms/step - loss: 2.2453 - acc: 0.6400 - val_loss: 2.1583 - val_acc: 0.5200
# Epoch 4/50
# 5/5 [==============================] - 0s 68ms/step - loss: 1.4204 - acc: 0.6800 - val_loss: 0.8468 - val_acc: 0.7300
# Epoch 5/50
# 5/5 [==============================] - 0s 67ms/step - loss: 0.6458 - acc: 0.8000 - val_loss: 0.2497 - val_acc: 0.9200
# Epoch 6/50
# 5/5 [==============================] - 0s 71ms/step - loss: 0.3850 - acc: 0.9000 - val_loss: 0.1819 - val_acc: 0.9300
# Epoch 7/50
# 5/5 [==============================] - 0s 68ms/step - loss: 0.4160 - acc: 0.8500 - val_loss: 0.5346 - val_acc: 0.8000
# Epoch 8/50
# 5/5 [==============================] - 0s 69ms/step - loss: 0.3907 - acc: 0.8500 - val_loss: 0.4460 - val_acc: 0.8700
# Epoch 9/50
# 5/5 [==============================] - 0s 72ms/step - loss: 0.2791 - acc: 0.9100 - val_loss: 0.1606 - val_acc: 0.9200
# Epoch 10/50
# 5/5 [==============================] - 0s 74ms/step - loss: 0.1585 - acc: 0.9600 - val_loss: 0.1050 - val_acc: 0.9500
# Epoch 11/50
# 5/5 [==============================] - 0s 71ms/step - loss: 0.1377 - acc: 0.9400 - val_loss: 0.0601 - val_acc: 0.9600
# Epoch 12/50
# 5/5 [==============================] - 0s 72ms/step - loss: 0.1057 - acc: 0.9500 - val_loss: 0.1328 - val_acc: 0.9500
# Epoch 13/50
# 5/5 [==============================] - 0s 70ms/step - loss: 0.1045 - acc: 0.9500 - val_loss: 0.0666 - val_acc: 0.9700
# Epoch 14/50
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0825 - acc: 0.9600 - val_loss: 0.0228 - val_acc: 1.0000
# Epoch 15/50
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0296 - acc: 1.0000 - val_loss: 0.0166 - val_acc: 1.0000
# Epoch 16/50
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0339 - acc: 1.0000 - val_loss: 0.0228 - val_acc: 1.0000
# Epoch 17/50
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0196 - acc: 1.0000 - val_loss: 0.0151 - val_acc: 1.0000
# Epoch 18/50
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0113 - acc: 1.0000 - val_loss: 0.0122 - val_acc: 1.0000
# Epoch 19/50
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0119 - acc: 1.0000 - val_loss: 0.0089 - val_acc: 1.0000
# Epoch 20/50
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0114 - acc: 1.0000 - val_loss: 0.0102 - val_acc: 1.0000
# Epoch 21/50
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0085 - acc: 1.0000 - val_loss: 0.0094 - val_acc: 1.0000
# Epoch 22/50
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0091 - acc: 1.0000 - val_loss: 0.0077 - val_acc: 1.0000
# Epoch 23/50
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0079 - acc: 1.0000 - val_loss: 0.0075 - val_acc: 1.0000
# Epoch 24/50
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0088 - acc: 1.0000 - val_loss: 0.0074 - val_acc: 1.0000
# Epoch 25/50
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0079 - acc: 1.0000 - val_loss: 0.0077 - val_acc: 1.0000
# Epoch 26/50
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0072 - acc: 1.0000 - val_loss: 0.0073 - val_acc: 1.0000
# Epoch 27/50
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0072 - acc: 1.0000 - val_loss: 0.0066 - val_acc: 1.0000
# Epoch 28/50
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0070 - acc: 1.0000 - val_loss: 0.0065 - val_acc: 1.0000
# Epoch 29/50
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0065 - acc: 1.0000 - val_loss: 0.0063 - val_acc: 1.0000
# Epoch 30/50
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0064 - acc: 1.0000 - val_loss: 0.0061 - val_acc: 1.0000
# Epoch 31/50
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0063 - acc: 1.0000 - val_loss: 0.0060 - val_acc: 1.0000
# Epoch 32/50
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0060 - acc: 1.0000 - val_loss: 0.0058 - val_acc: 1.0000
# Epoch 33/50
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0058 - acc: 1.0000 - val_loss: 0.0058 - val_acc: 1.0000
# Epoch 34/50
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0058 - acc: 1.0000 - val_loss: 0.0056 - val_acc: 1.0000
# Epoch 35/50
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0057 - acc: 1.0000 - val_loss: 0.0056 - val_acc: 1.0000
# Epoch 36/50
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0055 - acc: 1.0000 - val_loss: 0.0055 - val_acc: 1.0000
# Epoch 37/50
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0057 - acc: 1.0000 - val_loss: 0.0052 - val_acc: 1.0000
# Epoch 38/50
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0052 - acc: 1.0000 - val_loss: 0.0053 - val_acc: 1.0000
# Epoch 39/50
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0053 - acc: 1.0000 - val_loss: 0.0050 - val_acc: 1.0000
# Epoch 40/50
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0051 - acc: 1.0000 - val_loss: 0.0049 - val_acc: 1.0000
# Epoch 41/50
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0050 - acc: 1.0000 - val_loss: 0.0049 - val_acc: 1.0000
# Epoch 42/50
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0049 - acc: 1.0000 - val_loss: 0.0048 - val_acc: 1.0000
# Epoch 43/50
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0048 - acc: 1.0000 - val_loss: 0.0046 - val_acc: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0047 - acc: 1.0000 - val_loss: 0.0046 - val_acc: 1.0000
# Epoch 45/50
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0047 - acc: 1.0000 - val_loss: 0.0045 - val_acc: 1.0000
# Epoch 46/50
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0044 - acc: 1.0000 - val_loss: 0.0044 - val_acc: 1.0000
# Epoch 47/50
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0045 - acc: 1.0000 - val_loss: 0.0043 - val_acc: 1.0000
# Epoch 48/50
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0043 - acc: 1.0000 - val_loss: 0.0043 - val_acc: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0042 - acc: 1.0000 - val_loss: 0.0041 - val_acc: 1.0000
# Epoch 50/50
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0043 - acc: 1.0000 - val_loss: 0.0041 - val_acc: 1.0000

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 50), H.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), H.history["acc"], label="train_acc")
plt.plot(np.arange(0, 50), H.history["val_acc"], label="val_acc")
plt.title("Accuracy Plot")
plt.xlabel("Epoch #")
plt.ylabel("Acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report

pred = model.predict(x_val)
labels = (pred > 0.5).astype(np.int)

print(classification_report(y_val, labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       1.00      1.00      1.00        50
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
